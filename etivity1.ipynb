# %% [markdown]
# # Cian McInerney - 17232724 - Etivity 1 : EDA

# %% [markdown]
# # Task 1: Exploratory Data Analysis Question

# %% [markdown]
# Is there a correlation between a person having a loan based on their level of education?

# %% [markdown]
# # Importing Modules

# %%
# importing the Python modules 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading in data
# reading in bank.csv file

# %%
# This is used to read the data from the csv file. 
df = pd.read_csv('https://raw.githubusercontent.com/CianMc98/CS4168-DataMining/main/bank.csv')
df
# Out:
#        age           job   marital  ... previous poutcome  subscribed
# 0     32.0    technician    single  ...        2  failure          no
# 1     39.0    technician  divorced  ...        1  failure          no
# 2     59.0       retired   married  ...        1  failure          no
# 3     47.0   blue-collar   married  ...        2  failure          no
# 4     54.0       retired   married  ...        1  failure          no
# ...    ...           ...       ...  ...      ...      ...         ...
# 1995  20.0       student    single  ...        0      NaN         yes
# 1996  28.0        admin.    single  ...        0      NaN         yes
# 1997  81.0       retired   married  ...        0      NaN         yes
# 1998  46.0      services   married  ...        0      NaN         yes
# 1999  40.0  entrepreneur   married  ...        0      NaN         yes
#
# [2000 rows x 17 columns]

# %% [markdown]
# # Task 2: Calculate statistics for the numerical and categorical attributes

# %% [markdown]
# ## Describing All Data

# %%
# this uses dataframe to describe all the data in the csv file
df.describe(include='all')
# Out:
#                 age         job  marital  ...     previous poutcome  subscribed
# count   1988.000000        1990     2000  ...  2000.000000     1546        2000
# unique          NaN          11        3  ...          NaN        3           2
# top             NaN  management  married  ...          NaN  failure          no
# freq            NaN         461     1111  ...          NaN      955        1000
# mean      41.753018         NaN      NaN  ...     2.561500      NaN         NaN
# std       12.724358         NaN      NaN  ...     3.400735      NaN         NaN
# min       18.000000         NaN      NaN  ...     0.000000      NaN         NaN
# 25%       32.000000         NaN      NaN  ...     1.000000      NaN         NaN
# 50%       38.000000         NaN      NaN  ...     2.000000      NaN         NaN
# 75%       50.000000         NaN      NaN  ...     3.000000      NaN         NaN
# max       93.000000         NaN      NaN  ...    55.000000      NaN         NaN
#
# ...

# %% [markdown]
# ### Explaination:
# By using include = all, it includes all columns in the dataset.
#
# The NaN means not a number as the df.describe() analyses the data as numerical by default.
# As some of the columns are categorical data, it can not be described in the same way as numerical data.

# %% [markdown]
# ## Describing Numerical Data

# %%
# by default, numerical data is described 
df.describe()
# NOTE: age has 12 missing values in the dataset
# Out:
#                age       balance  ...        pdays     previous
# count  1988.000000   2000.000000  ...  2000.000000  2000.000000
# mean     41.753018   1413.663500  ...   167.896000     2.561500
# std      12.724358   3131.224213  ...   131.754126     3.400735
# min      18.000000   -980.000000  ...    -1.000000     0.000000
# 25%      32.000000    201.500000  ...    75.750000     1.000000
# 50%      38.000000    551.000000  ...   182.000000     2.000000
# 75%      50.000000   1644.500000  ...   251.000000     3.000000
# max      93.000000  81204.000000  ...   854.000000    55.000000
#
# [8 rows x 7 columns]

# %% [markdown]
# ### Explaination:
# Age - The mean age is 41, the youngest being 18 and oldest 93. The standard deviation is 12.7
#
# Balance - The mean balance is over 1413, the minimum is -980 and max is 81,204. The standard deviation is 3131.
#
# Duration - The mean duration is 292, the std is 221. The minimum duration is 7 and max is 1823 days.
#
# Campaign - The maximum number of campaigns is 11, the min is 1 and average is 1.9.
#
# Pdays - The mean is 167, the standard deviation is 131. The max is 854 and min is -1.
#
# Previous - The maximum value is 55, minimum is 0. The mean value is 2.56 and std is 3.4.

# %% [markdown]
# ## Describing Categorical Data

# %%
# this includes the categorical data to be described with dataframe
df.describe(include='O')
# Out:
#                job  marital  education  ... month poutcome subscribed
# count         1990     2000       1896  ...  2000     1546       2000
# unique          11        3          3  ...    12        3          2
# top     management  married  secondary  ...   feb  failure         no
# freq           461     1111        995  ...   404      955       1000
#
# [4 rows x 10 columns]

# %% [markdown]
# ### Conclusion

# %% [markdown]
# The categorical data was described above and these are the main takeaways:
#
# There is 10 missing values in the job column. 11 unique jobs of those found in the dataset, with the most frequent job being management.
#
# There are 3 types of martial status: married, single or divorced.
#
# The three types of education are; primary, tertiary and secondary. Most people have at least second level education. however there are some missing values in the dataset.
#
# Most people do not have their own housing loans, even more dont have a personal loan and nearly all have cellular as a contact method. The contact column has 191 missing values
#
# February is the most frequent month in the dataset.
#
# There are three outcomes in the poutcome column; success, failure and other. Failure is the most popular with over 60%, however there is 454 of missing values in this column.
#
# This is an even split of subscribers with 1000 being subscribers and 1000 being non-subscribers.
#
# As there is missing values in some of the columns, it is important to note that the findings may not be completely accurate. The next step is to go into more detail in the analysis and display my findings graphically.

# %% [markdown]
# # Heatmap and Pairplot

# %%
# heatmap for the dataset's correlation 
sns.heatmap(df.corr());

# %%
# pairplots for age, balance, day and duration
sns.pairplot(data=df[['age','balance','day','duration', 'campaign', ]])
plt.show()

# %% [markdown]
# # Analysing Data

# %%
df['age'].value_counts()
# Out:
# 33.0    95
# 35.0    90
# 31.0    87
# 34.0    84
# 32.0    77
#         ..
# 86.0     2
# 76.0     2
# 81.0     2
# 18.0     1
# 79.0     1
# Name: age, Length: 68, dtype: int64

# %%
df['education'].value_counts()
# Out:
# secondary    995
# tertiary     684
# primary      217
# Name: education, dtype: int64

# %%
df['balance'].value_counts()
# Out:
# 0       86
# 1        9
# 272      8
# 303      7
# 4        6
#         ..
# 1057     1
# 5151     1
# 1053     1
# 1047     1
# 4873     1
# Name: balance, Length: 1274, dtype: int64

# %%
df['housing'].value_counts()
# Out:
# no     1037
# yes     963
# Name: housing, dtype: int64

# %%
df['loan'].value_counts()
# Out:
# no     1750
# yes     250
# Name: loan, dtype: int64

# %%
# this will display the missing values in each column.
df.isnull().sum()
# Out:
# age            12
# job            10
# marital         0
# education     104
# default         0
# balance         0
# housing         0
# loan            0
# contact       191
# day             0
# month           0
# duration        0
# campaign        0
# pdays           0
# previous        0
# poutcome      454
# subscribed      0
# dtype: int64

# %% [markdown]
# # Task 3: Plotting dataset
# Use at least two different plotting techniques to plot the distribution of some numerical attributes

# %%
# Plotting a histogram for balance

df['balance'].hist(bins=40)
plt.xlabel('Balance Amount')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Balance Boxplot

# %%
# boxplot for balance
df.boxplot(column='balance')
plt.show()

# %% [markdown]
# ### Conclusion
# Most values in the balance column are clustered closely together, however it is clear there is an outlier in the data with a balance at 81,204 and from the minimum number being -980 it distorts the boxplot.

# %%
df[df['balance']==df['balance'].max()]
# Out:
#        age      job  marital  education  ... pdays  previous poutcome subscribed
# 1033  84.0  retired  married  secondary  ...    94         3  success        yes
#
# [1 rows x 17 columns]

# %%
df[df['balance']==df['balance'].min()]
# Out:
#       age         job   marital education  ... pdays  previous poutcome subscribed
# 306  39.0  management  divorced  tertiary  ...   260         1  failure         no
#
# [1 rows x 17 columns]

# %% [markdown]
# ## Age Boxplot

# %%
# boxplot for age
df.boxplot(column='age')
plt.show()

# %% [markdown]
# ### Conclusion
# At a glance, there are several outliers in the age column dataset including the biggest outlier at 93. There minimum age is 18. Q1 is 32 and Q3 is 50. The median is just under 40.

# %%
df[df['age']==df['age'].max()]
# Out:
#        age      job  marital education  ... pdays  previous poutcome subscribed
# 1182  93.0  retired  married       NaN  ...    13         9  success        yes
# 1370  93.0  retired  married       NaN  ...   177         7  success        yes
#
# [2 rows x 17 columns]

# %%
df[df['age']==df['age'].min()]
# Out:
#        age      job marital education  ... pdays  previous poutcome subscribed
# 1709  18.0  student  single       NaN  ...    -1         0      NaN        yes
#
# [1 rows x 17 columns]

# %% [markdown]
# ## Additional Diagrams

# %%
#Swarmplot for age 

sns.swarmplot(y=df['age'], orient='v', size = 2.5)
plt.show()

# %%
# Boxplots of balance, grouped by the categorical attribute Education
df.boxplot(column='balance', by='education')
plt.title('Box plot of balance grouped by education')
plt.suptitle("") 
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# In the boxplot above, it shows the main outlier is at 82,204 balance and attended secondary education.

# %%
# Boxplots of balance, grouped by the numerical attribute loan
df.boxplot(column='balance', by='loan')
plt.title('Box plot of balance grouped by loan')
plt.suptitle("") 
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
# Boxplots of balance, grouped by the numerical attribute housing
df.boxplot(column='balance', by='housing')
plt.title('Box plot of balance grouped by housing')
plt.suptitle("") 
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
# scatterplot for balance and age
df.plot.scatter(x='balance', y='age')
plt.show()

# %% [markdown]
# The outlier is also visibile in this scatterplot.

# %%
sns.violinplot(data=df, x='education', y='age')
plt.show()

# %% [markdown]
# # Task 4: Generate two plots with the combined distribution of attributes

# %%
df = df.replace({'housing': {'yes': 1, 'no': 0}}) 
df
# Out:
#        age           job   marital  ... previous poutcome  subscribed
# 0     32.0    technician    single  ...        2  failure          no
# 1     39.0    technician  divorced  ...        1  failure          no
# 2     59.0       retired   married  ...        1  failure          no
# 3     47.0   blue-collar   married  ...        2  failure          no
# 4     54.0       retired   married  ...        1  failure          no
# ...    ...           ...       ...  ...      ...      ...         ...
# 1995  20.0       student    single  ...        0      NaN         yes
# 1996  28.0        admin.    single  ...        0      NaN         yes
# 1997  81.0       retired   married  ...        0      NaN         yes
# 1998  46.0      services   married  ...        0      NaN         yes
# 1999  40.0  entrepreneur   married  ...        0      NaN         yes
#
# [2000 rows x 17 columns]

# %% [markdown]
# ### Explaination:
# In the frequency table below, it shows that 217 people have primary education experience, 684 have tertiary education and 995 have secondary education.

# %%
frequency_table = df['education'].value_counts(ascending=True)
print('Frequency Table for Education:') 
print(frequency_table)
# Out:
# Frequency Table for Education:
# primary      217
# tertiary     684
# secondary    995
# Name: education, dtype: int64

# %%
# Plot the frequency table for education
frequency_table.plot(kind='bar', color = ['red', 'orange', 'green'])
plt.xlabel('Education')
plt.ylabel('Frequency')
plt.title('Education distribution')
plt.show()

# %% [markdown]
# ## Pivot Table
# Pivot table for people with personal loans based on their education level.
#
#
# *   Primary - 11%
# *   Secondary - 14%
# *   Tertiary - 11%

# %%
pivot_table_LC = df.pivot_table(values='loan',
                                index='education',
                                aggfunc=lambda x: x.map({'yes':1, 'no':0}).mean())

# %%
print(pivot_table_LC)
# Out:
#                loan
# education
# primary    0.110599
# secondary  0.144724
# tertiary   0.114035

# %%
# Plot pivot table
pivot_table_LC.plot(kind='bar')
plt.xlabel('Education Level')
plt.ylabel('Probability of personal loan ')
plt.title('Probability of personal loan based on their education')
plt.legend().set_visible(False)

# %% [markdown]
# ## Stacked Chart
#
# This stacked chart shows the correlation between if a person has a personal loan and a housing loan. This shows that more people dont have any sort of loan and fewer again have both a personal and house loan

# %%
# Use crosstab function to create a stacked chart of personal loan and housing loan
crosstab_CL = pd.crosstab(df['housing'], df['loan'])
crosstab_CL.plot(kind='bar', stacked=True, color=['red', 'green'])
plt.ylabel('Number of Applicants')
plt.show()

# %% [markdown]
# ## Advanced Stacked Chart
# In this stacked chart, I have added an education tab to examine the relationship with the different levels of education and people having loans.

# %%
# Added education to the stackchart to examine the relationship with education and if they had any loan.
df = df.replace({'housing': { 1 :  'yes', 0 : 'no'}}) 
crosstab_CGL = pd.crosstab([df['housing'], df['loan']], df['education'])
crosstab_CGL.plot(kind='bar', stacked=True, color=['red', 'orange', 'green'], grid=False)
plt.ylabel('Number of Applicants')
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# It is quite evident that the majority of people do not have loans.
# The number of those that have personal loans and dont have housing loans is extremely low in comparison to those who have housing loans and dont have personal loans.
# Less than 200 people have both types of loans and over 800 have no loans at all.
# The higher the person's balance is the more likely they are to not have a loan.
# Those that have tertiary level education are highly unlikely to have any form of loans or a personal loan.
# There is an even spread on those with primary and secondary education and no loans with those with a housing loan only.
